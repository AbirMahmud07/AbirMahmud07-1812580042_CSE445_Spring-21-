# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# import data set
path = r"C:\Users\TOSHIBA\Desktop\audit_data\audit_risk.csv"
df = pd.read_csv(path)

# %%
# Show data
df.head
# Out:
# <bound method NDFrame.head of      Sector_score LOCATION_ID  PARA_A  Score_A  Risk_A  PARA_B  Score_B  \
# 0            3.89          23    4.18      0.6   2.508    2.50      0.2
# 1            3.89           6    0.00      0.2   0.000    4.83      0.2
# 2            3.89           6    0.51      0.2   0.102    0.23      0.2
# 3            3.89           6    0.00      0.2   0.000   10.80      0.6
# 4            3.89           6    0.00      0.2   0.000    0.08      0.2
# ..            ...         ...     ...      ...     ...     ...      ...
# 771         55.57           9    0.49      0.2   0.098    0.40      0.2
# 772         55.57          16    0.47      0.2   0.094    0.37      0.2
# 773         55.57          14    0.24      0.2   0.048    0.04      0.2
# 774         55.57          18    0.20      0.2   0.040    0.00      0.2
# 775         55.57          15    0.00      0.2   0.000    0.00      0.2
#
#      Risk_B  TOTAL  numbers  ...  RiSk_E  History  Prob  Risk_F  Score  \
# ...

# %%
df.tail()
# Out:
#      Sector_score LOCATION_ID  PARA_A  Score_A  Risk_A  PARA_B  Score_B  \
# 771         55.57           9    0.49      0.2   0.098    0.40      0.2
# 772         55.57          16    0.47      0.2   0.094    0.37      0.2
# 773         55.57          14    0.24      0.2   0.048    0.04      0.2
# 774         55.57          18    0.20      0.2   0.040    0.00      0.2
# 775         55.57          15    0.00      0.2   0.000    0.00      0.2
#
#      Risk_B  TOTAL  numbers  ...  RiSk_E  History  Prob  Risk_F  Score  \
# 771   0.080   0.89      5.0  ...     0.4        0   0.2     0.0    2.0
# 772   0.074   0.84      5.0  ...     0.4        0   0.2     0.0    2.0
# 773   0.008   0.28      5.0  ...     0.4        0   0.2     0.0    2.0
# 774   0.000   0.20      5.0  ...     0.4        0   0.2     0.0    2.0
# 775   0.000   0.00      5.0  ...     0.4        0   0.2     0.0    2.0
#
#      Inherent_Risk  CONTROL_RISK  Detection_Risk  Audit_Risk  Risk
# ...

# %%
df.describe()
# Out:
#        Sector_score      PARA_A     Score_A      Risk_A       PARA_B  \
# count    776.000000  776.000000  776.000000  776.000000   776.000000
# mean      20.184536    2.450194    0.351289    1.351029    10.799988
# std       24.319017    5.678870    0.174055    3.440447    50.083624
# min        1.850000    0.000000    0.200000    0.000000     0.000000
# 25%        2.370000    0.210000    0.200000    0.042000     0.000000
# 50%        3.890000    0.875000    0.200000    0.175000     0.405000
# 75%       55.570000    2.480000    0.600000    1.488000     4.160000
# max       59.850000   85.000000    0.600000   51.000000  1264.630000
#
#           Score_B      Risk_B        TOTAL     numbers   Score_B.1  ...  \
# count  776.000000  776.000000   776.000000  776.000000  776.000000  ...
# mean     0.313144    6.334008    13.218481    5.067655    0.223711  ...
# std      0.169804   30.072845    51.312829    0.264449    0.080352  ...
# ...

# %%
df.shape
# Out:
# (776, 27)

# %%
df.columns
# Out:
# Index(['Sector_score', 'LOCATION_ID', 'PARA_A', 'Score_A', 'Risk_A', 'PARA_B',
#        'Score_B', 'Risk_B', 'TOTAL', 'numbers', 'Score_B.1', 'Risk_C',
#        'Money_Value', 'Score_MV', 'Risk_D', 'District_Loss', 'PROB', 'RiSk_E',
#        'History', 'Prob', 'Risk_F', 'Score', 'Inherent_Risk', 'CONTROL_RISK',
#        'Detection_Risk', 'Audit_Risk', 'Risk'],
#       dtype='object')

# %%
#Check unique value of the data set
df.nunique()
# Out:
# Sector_score       13
# LOCATION_ID        45
# PARA_A            363
# Score_A             3
# Risk_A            363
# PARA_B            358
# Score_B             3
# Risk_B            360
# TOTAL             471
# numbers             5
# Score_B.1           3
# Risk_C              5
# Money_Value       328
# Score_MV            3
# Risk_D            328
# District_Loss       3
# PROB                3
# RiSk_E              5
# History             7
# Prob                3
# Risk_F              7
# Score              17
# Inherent_Risk     584
# CONTROL_RISK       11
# Detection_Risk      1
# Audit_Risk        601
# Risk                2
# dtype: int64

# %%
df['Score'].unique()
# Out:
# array([2.4, 2. , 4.4, 3.2, 4.2, 3.6, 4. , 2.2, 3. , 2.6, 3.8, 3.4, 4.8,
#        2.8, 5.2, 4.6, 5. ])

# %%
#Check null value
df.isnull().sum()
# Out:
# Sector_score      0
# LOCATION_ID       0
# PARA_A            0
# Score_A           0
# Risk_A            0
# PARA_B            0
# Score_B           0
# Risk_B            0
# TOTAL             0
# numbers           0
# Score_B.1         0
# Risk_C            0
# Money_Value       1
# Score_MV          0
# Risk_D            0
# District_Loss     0
# PROB              0
# RiSk_E            0
# History           0
# Prob              0
# Risk_F            0
# Score             0
# Inherent_Risk     0
# CONTROL_RISK      0
# Detection_Risk    0
# Audit_Risk        0
# Risk              0
# dtype: int64

# %%
#fill null value 
df2 = df.fillna(df.mean())

# %%
#again check any value is missing or not
df2.isnull().sum()
# Out:
# Sector_score      0
# LOCATION_ID       0
# PARA_A            0
# Score_A           0
# Risk_A            0
# PARA_B            0
# Score_B           0
# Risk_B            0
# TOTAL             0
# numbers           0
# Score_B.1         0
# Risk_C            0
# Money_Value       0
# Score_MV          0
# Risk_D            0
# District_Loss     0
# PROB              0
# RiSk_E            0
# History           0
# Prob              0
# Risk_F            0
# Score             0
# Inherent_Risk     0
# CONTROL_RISK      0
# Detection_Risk    0
# Audit_Risk        0
# Risk              0
# dtype: int64

# %%
#Relationship analysis
corelation = df.corr()

# %%
sns.heatmap(corelation, 
        xticklabels=corelation.columns,
        yticklabels=corelation.columns, annot=True)
plt.show()
plt.savefig("Corelation.png", bbox_inches="tight")

# %%
#pair plot
sns.pairplot(df)
plt.savefig("pairplot.png", bbox_inches="tight")

# %%
df.columns
# Out:
# Index(['Sector_score', 'LOCATION_ID', 'PARA_A', 'Score_A', 'Risk_A', 'PARA_B',
#        'Score_B', 'Risk_B', 'TOTAL', 'numbers', 'Score_B.1', 'Risk_C',
#        'Money_Value', 'Score_MV', 'Risk_D', 'District_Loss', 'PROB', 'RiSk_E',
#        'History', 'Prob', 'Risk_F', 'Score', 'Inherent_Risk', 'CONTROL_RISK',
#        'Detection_Risk', 'Audit_Risk', 'Risk'],
#       dtype='object')
